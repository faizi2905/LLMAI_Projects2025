# %%
import tiktoken

tool = tiktoken.encoding_for_model("gpt-4.1-mini")
tokens = tool.encode("Hi, I am Faiz")

# %%
tokens
# Out:
# [12194, 11, 357, 939, 16792, 482]

# %%
for token in tokens:
    token_text = tool.decode([token])
    print(f"{token}:{token_text}")
# Out:
# 12194:Hi
# 11:,
# 357: I
# 939: am
# 16792: Fa
# 482:iz
